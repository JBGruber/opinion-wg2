# %%
#process data before using it
#lower case, strip, replace "-" with " ",... 


#list generic_approaches_no_tool: list_of _names_that_are_not_tools
#dictionary dict_standard_tool general_name:[list_of_other_names]



generic_approaches_no_tool = [
        
    'opinion mining', 'opinion mining', 'opinion mining (om)', 'opinion mining technology', 'comparative opinion mining',
    
    'classification algorithms', 'clustering analysis',
    
    'machine learning', 'machine learning models', 'machine learning algorithms',
    'machine learning approach', 'machine learning prediction model',
    'machine learning systems', 'machine learning methods', 'supervised machine learning',
    'supervised machine learning for text classification',
    
    'deep learning', 'deep learning models', 'deep learning techniques',
    'deep learning algorithms', 'deep learning based model', 'deep learning classifier',
    'deep learning classification algorithm', 'neural networks', 'neural nets',
    
    'transformer based models', 'transformer', 'transformer encoders', 'transformer encoder layers', 
    
    'lexicon', 'lexicon based system', 'lexicon based technique', 'lexicon based approach',
    'lexicon based approach (lba)',
    
    'sentiment analysis', 'sentiment classifier', 'online sentiment analysis', 'domain specific sentiment analysis',
    'sentiment analysis engine', 'sentiment analysis tool', 'hybrid sentiment analysis approach',
    'sentiment analysis system', 'sentiment analysis (sa)', 'sentiment analysis methods',
    'sentiment analysis algorithm', 'sentiment analysis tools', 'sentiment analysis opinion mining',
    'fuzzy sentiment analysis', 'lexicon based sentiment analysis',
       
    'crawler technology', 
    'link prediction methods',
    
    'sentiment connection weights', 
    'twitter sentiment tools', 'twitter sentiment',
       
    'nlp tool kits',
    
    'attention mechanism', 'self attention mechanism',
    
    'api webtool', 'api webtools',
    'fuzzy logic', 'fuzzy logic system',
    
    'semantic network analysis', 

    'neural network intelligence',
    'federated deep neural network',
    
    'natural language processing', 'natural language processing (nlp)',
        'natural language processing techniques', 'natural language processing technology',
        'natural language processing pipeline', 'natural language processing algorithm',
        'natural language processing based tool',
    
    'text mining', 'text mining procedure', 'text mining methods', 'text mining method', 'text mining for opinion score',
    
    'embedding layer', 'word embedding', 'word embeddings', 
    'sentiment lexicon',
        'lexicon dictionary', 'opinion lexicon', 'dynamic lexicons', 'domain based lexicons',
        'lexicon based features', 
    
    'attention', 'self attention network',
    
    'neural network', 'simple neural network', 
    
    'unsupervised machine learning (topic modeling)',
    'topic modeling', 'probabilistic topic modeling', 'topic model', 'dynamic topic models', 
    
    'hybrid method',   
    
    'content analysis', 'text analysis', 'lexical analysis',
        
    'social network analysis', 'semantic network analysis',
         
    'aspect based sentiment analysis', 'aspect based sentiment analysis (absa)', 'absa', 
    'ontology driven aspect based sentiment analysis',
    'weakly supervised framework for aspect based sentiment analysis',
    'labeling tool for aspect based sentiment analysis', 'aspect based sentiment analysis tool',
    
    
    'text classifier', 'name classifier', 'meta classifier',
        'ensemble classifier', 'voting ensemble', 'ensemble learning',
        'transfer learning', 'word vectors', 'distributed document representation',
        
    'regression analysis', 'regression models', 'statistical model',
    
    'sentiment integrated critiquing system',
    'decision support framework', 
    'expert systems', 'expert system',
    
    'knowledge graphs', 'semantic web technologies', 'ontology alignment',
    'data mining',
    
    'association rule mining', 'association rule mining (arm)',
    
    'content based filtering', 
    'collaborative filtering', 
    'matrix factorization',
    
    'online polls', 
    
    'aspect based opinion mining framework',
    
    'cloud based software tool for sentiment analysis',
    'graph based semi supervised learning', 'graph based semi supervised learning algorithm',
    'structured prediction models', 
    
    'natural language understanding',
    'heuristic deep learning method', 
    'deep learning model',
    'hybrid deep learning model', 'fuzzy clustering', 
    'social graph clustering',
        'hierarchical cluster analysis', 'agglomerative clustering',
        'word sense disambiguation algorithm', 'negation handling technique',
        'ranking algorithm', 'single pass algorithm', 'single pass clustering algorithm',
        'graph based co ranking algorithm', 'semantic similarity algorithm',
        'micro blog text mining',
        'adaptive instance based learning', 'evolutionary strategy algorithm',
        'simulated annealing algorithm', 'genetic programming',
        'neural variational inference', 'joint tensor factorization',
        'visualization techniques for sentiment data', 
    'interactive survey browser',
        'reputation generation approach', 'sentic computing based sentiment analysis framework',
        'retrieve and edit', 'multiple dictionaries', 'word lists',
        'semantic orientation analysis', 'bibliographic coupling',
        'hypertext induced topic selection algorithm', 'correspondence learning',
           
        'twitter data extraction and analysis framework',
        'feature based twitter sentiment analysis system',
        'argument mining tools',
        'emojis features', 'emoji training heuristic',
        'twitter hashtags' 
    ]




dict_standard_tool = { 
    
# Programming languages/platforms
"programming_language": [
        'python', 'python 3', 'python 3.10.0', 'r', 'r language', 'r programming',
        'r programming software', 'r statistical software', 'r software', 'r tool',
        'matlab', 'sql', 'prolog', 'python script for data extraction', 'python libraries',
        'python software', 'python crawler', 'python 3 scraper'],

# General libraries/frameworks (not ML-specific tools)
"general_libs": [
        'numpy', 'pandas', 'matplotlib', 'seaborn', 'plotly', 'mathplotlib',
        'plotrix', 'scales', 'broom', 'lubridate', 'tidyverse', 'stringr',
        'plyr', 'httr', 'rvest', 'django', 'flask',
        'bootstrap', 'rabbitmq', 'kafka', 'mongodb', 'jena', 'sql'],

# IDEs/Software tools
"ides_software_tools": [
        'r studio', 'rstudio', 'spyder', 'visual studio code',
        'rapidminer', 'rapid miner', 'rapidminer v9.9', 'weka', 'orange software',
        'orange', 'orange canvas', 'knime', 'tableau', 'tableau data analytics',
        'gephi', 'nodexl', 'nvivo', 'nvivo 12 plus', 'nvivo pro 12', 'nvivo12',
        'qsr nvivo pro 11.0', 'textom', 'textom 4.5', 'ucinet 6.0', 'ucinet',
        'netdraw', 'kh coder', 'maxqda', 'spss',
        'spss 25.0', 'ibm spss statistics 25', 'ibm spss modeler text analytics',
        'sas text miner', 'sas text miner 12.1', 'eviews', 'power bi',
        'microsoft excel 2007', 'vosviewer', 'limesurvey', 'shiny'
    ],

    
# Data collection/scraping tools/datasets
"data_collection_tools": [
        'tweepy', 'tweepy.py', 'tweepy api', 'snscrape', 'twint',
        'twitter intelligence tool (twint)', 'scrapy', 'scrapy redis bloomfilter',
        'beautiful soup', 'selenium', 'python seleniumwebdriver',
        'twitter api', 'twitter streaming api', 'twitter search api', 'twitter rest api',
        'twitter streaming application programming interface (api)',
        'python twitter api', 'python api for twitter', 'twitter4j',
        'youtube data api', 'facebook api', 'facebook graph api',
        'facebook4j api', 'facebook4j', 'instagram api',
        'instagram scraper', 'instagram php scraper',
        'twitter archiving google sheet', 'twitter scraper', 'twitter crawler',
        'getoldtweets3', 'optimized modified getoldtweets3 omgot',
        'exportcomments', 'socialgrep exports', 'twitterscraper',
        'octopus data collector', 'octopus collector', 'octopus', 'octopus v7.1',
        'gooseeker', 'twitteroauth', 'twitter package', 'twitter',
        'gtrendr', 'rtweet', 'rtweet package', 'rtexttools',
        'roauth', 'netvizz', 'zapier', 'hootsuite', 'mozdeh',
        'mozdeh big data analysis tool', 'netlytic', 'discovertext',
        'drone emprit academic', 'hydrator', 'outscraper', 'scraper',
        'weibo crawler', 'perl web crawler', 'google trends',
        'yahoo! finance api', 'r twitter package', 'twarc2',
        'google api', 'aylien api', 'aylien text api', 'aylien text analysis api',
        'text analytics api', 'alchemy language api', 'houndify api',
        'google geocoding web service', 'rfacebook library',
        'apollo social sensing tool','sentiment 140'
        ],
    

#Big data infrastructure 
"Big data infrastructure": [
        'apache flume', 'hadoop distributed file system (hdfs)', 'hdfs',
        'hadoop', 'apache hadoop', 'hadoop mapreduce', 'mapreduce', 'map reduce',
        'apache spark', 'spark', 'apache spark mllib', 'spark mllib', 'sparkml',
        'apache kafka', 'hive', 'apache hive', 'pig', 'apache pig',
        'apache zeppelin', 'apache lucene and solr', 'lucene', 'apache solr',
        'elk stack', 'elastic search'],   

# Now handle actual ML tools/models with standardization
# Naive Bayes variants
'naive_bayes' : ['naive bayes', 'naïve bayes', 'naive bayes classifier', 'naïve bayes classifier',
                'naive bayes algorithm', 'naive bayes classification', 'naive bayesian', 'naïve bayesian',
                'naive bayesian classification', 'naïve bias', 'naïve base classifier', 'nb',
                'naïve bayes (nb)', 'naive bayes classifier (nbc)', 'naïve bayes analyzer',
                'textblob naive bayes analyzer', 'naivebayes classifier', 'naïve bayes machine learning algorithm',
                'gaussian naive bayes',
                'multinomial naive bayes', 'multinomial naïve bayes', 'multinomial naive bayes classifier',
                'multinomial naïve bayes classifier', 'multinomial naive bayes (mnb)', 'mnb',
                'bernoulli naive bayes', 'bernoulli naïve bayes', 'bernoulli\'s naive bayes',
                'bernoulli nb model', 'bnb',
                'complement naive bayes (complementnb)', 'complement naïve bayes'],

# SVM variants
'svm': ['svm', 'support vector machine', 'support vector machines', 'support vector machine (svm)',
                'svm (support vector machine)', 'support vector machine classifier', 'svm.svc', 'svm classifier',
               'linear support vector machine',
       'svm rbf'],
'svc': ['support vector classification (svc)', 'support vector classifier',
                'support vector classifier (svc)', 'linear svc', 'linear support vector classification', 'linear svc model',
                'linear support vector classifiers', 'linearsvc'],
'svr': ['support vector regression'],


# Random Forest
'random_forest': ['random forest', 'random forests classifier', 'random forest classifier',
                'rf', 'random forest (rf)', 'boosted random forest', 'random forest tree',
                'random forest machine learning algorithm'],
# Decision Tree
'decision_tree': ['decision tree', 'decision tree classifier', 'decision tree algorithm',
                'decision tree (dtree)', 'dt', 'decision trees'],
'cart': [    'cart',        'classification and regression tree',       'decision tree classifier cart'    ],
'id3': [        'id3',        'id3 decision tree'    ],
'j48': [        'j48',        'j48 algorithm'    ],
'c4_5': [        'c4.5 decision tree'    ],
'extra_trees': ['extra trees', 'extra tree classifier'],

# KNN
'knn': ['k nearest neighbor (knn)', 'k nearest neighbor', 'k nearest neighbors',
                'k nearest neighbor (k nn)', 'k nearest neighbours', 'k nearest neighbour',
                'k nearest neighbors (knn)', 'knn', 'k nn', 'knn classifier', 'k nearest neighbors'],
# Gradient Boosting
'gradient_boosting': ['gradient boosting', 'gradient boosting classifier', 'gradient boost tree', 'gbm'],
'lightgbm': ['lightgbm', 'light gradient boosting machine', 'light gradient boosted machine'],
'xgboost': ['xgboost', 'xgboost classifier', 'xg boost'],
'catboost': ['catboost classifier'],
'adaboost': ['adaboost', 'ada boost', 'adaptive boosting'],
'gbdt': ['gbdt', 'gradient boosted decision tree classifier (gbdt)'],
    
#LLM models
'gpt': ['gpt','gpt 3', 'gpt-3','gpt 3.5', 'gpt-3.5','chatgpt'],    
#BERT
"bert": ['albert', 'distilbert','roberta', 'roberta model','bert', 'bert base', 'bert base uncased',
        'multilingual bert', 'mbert', 'm bert',
        'bert base multilingual uncased', 'bert base-multilingual-uncased',
        'bert base', 'bert base uncased', 'bert base-uncased',
        'bert', 'bert embeddings', 'bert tokenizer',
        'bidirectional encoder representations from transformers (bert)',
        'deberta',
        'keybert' ],
'xlnet':['xlnet'],
'bart': ['bart'],
't5': ['t5'],
'electra': ['electra'],
'longformer': ['longformer'],
'ernie': ['ernie'],
'elmo': ['elmo'],

# CNN
"cnn": ['cnn', 'convolutional neural network (cnn)', 'cnn (convolutional neural network)', 'cnns',
        'textcnn','rcnn',
       'convolutional neural network',
        'convolutional neural network (cnn)', 'convolutional neural networks', 'convolutional neural networks (cnn)',
        'convolution neural networks (cnn)', 'convolution neural network',
       'unsupervised convolutional neural network'],
'capsnet':['capsnet', 'capsule network'],
    
 # RNN/LSTM/GRU
'rnn': ['rnn', 'recurrent neural network (rnn)','recurrent neural networks', 'recurrent neural networks (rnn)'],

'gru': ['gru', 'gated recurrent unit (gru)', 'gated recurrent units (gru)','bigru', 'bi gru', 'bidirectional gated recurrent unit (bigru)',
                'bidirectional gated recurrent neural network', 'bidirectional gru'],

"lstm": ['lstm', 'long short term memory (lstm)', 'long short term memory', 'lstm neural networks',
 'bidirectional lstm', 'bi directional lstm', 'bi directional long short term memory',
                'bidirectional long short term memory (bilstm)', 'bilstm', 'bi lstm'],
'dnn': ['dnn', 'deep neural network (dnn)',
           'deep neural network', 'deep neural network (dnn)',
        'deep neural network model', 'deep neural networks',
        'feed forward neural network', 'deep learning neural network'],
'ann': ['ann', 'artificial neural networks', 'artificial neural networks (ann)', 'artificial neural network',
        'artificial neural network (ann)'],
'dbn': ['dbn', 'deep belief network', 'dbn (deep belief network)', 'deep belief neural networks (dbn)'],
'mlp': ['mlp', 'multi layer perceptron', 'multilayer perceptron', 'multi layer perceptron (mlp)'],


# Word embeddings

'word2vec': ['word2vec', 'google word2vec', 'word2vector'],
'glove': ['glove', 'stanford glove', 'glove word embedding'],
'fasttext': ['fasttext'],
'doc2vec': ['doc2vec', 'document vector representation (doc2vec)'], 
'sentence_transformers': ['sentence transformers', 'sentence transformer'],


# Sentiment analysis tools
'vader': ['vader', 'vader sentiment analyzer', 'vader analysis tool',
                'vader sentiment intensity analyzer', 'vader sentiment analysis', 'vader sentiment',
                'vader lexicon', 'vadersentiment', 'valence aware dictionary and sentiment reasoner (vader)',
                'valence aware dictionary for sentiment reasoning (vader)',
                'valence aware dictionary sentiment reasoner (vader)',
                'valence aware dictionary and sentiment reasoner',
                'vader nltk sentiment analyser', 'nltk\'s vader analyzer', 'vader ext'],
'textblob': ['textblob', 'textblob package', 'textblob python library',
                'textblob api', 'text blob api', 'text blob', 'textblob lexicon'],
'sentiwordnet': ['sentiwordnet', 'senti word net', 'sentiwordnet lexicon',
                'sentiwordnet3.0', 'sentiwordnet 3.0', 'sentiwordnet 3.0.0', 'sentiwordsnet'],
'afinn': ['afinn', 'afinn lexicon', 'afinn 111', 'affin 111', 'afinn iii', 'afinn dictionary'],
'senticnet': ['senticnet'],
'bing': ['bing lexicon', 'bing'],
'nrc': ['nrc', 'nrc lexicon', 'nrc emotion lexicon', 'nrc library'],
'sentistrength': ['sentistrength'],
'sentimentr': ['sentimentr', 'sentimentr package'],
    
# LDA
'lda': ['lda', 'latent dirichlet allocation', 'latent dirichlet allocation (lda)',
                'lda (latent dirichlet allocation)', 'lda model', 'latent dirichlet allocation model',
                'lda algorithm', 'latent dirichlet allocation algorithm'],

'pca': ['pca', 'principal component analysis (pca)'],

'bertopic': ['bertopic'],

# NLP libraries

'nltk': ['nltk', 'natural language toolkit (nltk)', 'python nltk', 'nltk 2.0.4', 'nltk 3.0'],
'spacy':  ['spacy', 'spacy dependency parser', 'spacy entity analysis'],
'corenlp': ['corenlp', 'stanford corenlp', 'stanford core nlp', 'standfordcorenlp', 'stanford corenlp toolkit'],
'opennlp': ['opennlp', 'open nlp', 'apache opennlp'],
'gensim': ['gensim', 'gensim python library'],
'flair': ['flair'],
'stanza': ['stanza'],  #from stanfordnlp
'sklearn': ['scikit learn', 'sklearn', 'sci kit learn',
                'scikit learn (sklearn)', 'scikit learn python package'],

# Frameworks
'tensorflow': ['tensorflow'],
'keras': ['keras', 'keras with tensorflow', 'keras tokenizer'],
    
#TFIDF
'tfidf': ['tf idf', 'tf*idf', 'tfidf', 'tf–idf', 'tf idf vectorization',
            'term frequency inverse document frequency',
            'term frequency inverse document frequency (tf idf)',
            'termfrequency inverse document frequency (tf idf)', 'tf idf vectorizer', 'tfidf vectorizer', 'tfidfvectorizer'],    

#clustering 
'k_means': ['k means', 'k means clustering'],
'dbscan': ['dbscan'],

    
#statistcs and statistical models
'crf': ['crf', 'conditional random field (crf)', 'crf++', 'crfs', 'crf models', 'crf classifier'],
'linear_regression': ['linear regression'],
'ridge_regression': ['ridge regression'], 
'ridge_classifier': ['ridge classifier'],
'softmax': ['softmax', 'softmax regression'],
'logistic_regression': ['logistic regression', 'logistic regression model', 'lr',
                       'multinomial logistic regression', 'multinomial logistic regression model'],

# Other common tools
'bow': ['bow', 'bag of words', 'bag of words (bow)', 'bag of words'],
'countvectorizer': ['countvectorizer', 'count vectorizer', 'count vectorization'],
'smote': ['smote'],

'liwc': [ 'liwc', 'liwc 22', 'liwc 2015', 'liwc2015', 'linguistic inquiry and word count (liwc)'],
'opinionfinder': ['opinion finder', 'opinionfinder'],
'syuzhet': ['syuzhet', 'syuzhet r package'],
'tidytext': ['tidytext'],
'pyabsa': ['pyabsa'],
'wordcloud': ['wordcloud', 'word cloud'],
'maxent': ['maxent', 'maximum entropy', 'maximum entropy model'],
'pso': [  'pso', 'particle swarm optimization',   'particle swarm optimization (pso)'    ],
'genetic_algorithm': ['genetic algorithm', 'genetic algorithm (ga)', 'genetic algorithms'    ],
'hmm': ['hidden markov model', 'hidden markov models', 'hmm'  ],
'cosine_similarity': ['cosine similarity'],
'levenshtein': ['levenshtein', 'levenshtein distance'],
'wordnet': ['wordnet', 'wordnet similarity', 'wordnet affect'],
'babelnet': ['babelnet'],

'conceptnet': ['conceptnet'],
'sgd': ['sgd', 'stochastic gradient descent', 'stochastic gradient descent optimization algorithm'],
 'autocorrect': ['autocorrect'],
    'langdetect': ['langdetect'],
    'mallet': ['mallet', 'mallet java module'],
    'snownlp': ['snownlp'],
    'jieba': ['jieba', 'jieba chinese text segmentation', 'python jieba', 'jiebar'],
    'adam': ['adam'],
    'rake': ['rake'],
    'yake': ['yake'],
    'lime': ['lime'],
    'sbert': ['sbert'],
    'ulmfit': ['ulmfit'],
    'botometer': ['botometer', 'bot o meter'],
    'pattern': ['pattern', 'pattern library'],
    'emolex': ['emolex'],
    'numberbatch': ['numberbatch'],
    'deeppavlov': ['deeppavlov'],
    'zemberek': ['zemberek'],
    'hazm': ['hazm'],
    'tweetnlp': ['tweetnlp'],
    'ktrain': ['ktrain'],
    'praw': ['praw', 'python reddit api wrapper (praw)'],
    'anserini': ['anserini'],
    'leximancer': ['leximancer'],
    
#nlp apis    
'meaningcloud_nlp': ['meaningcloud', 'meaningcloud api', 'meaning cloud'],
'azure_nlp': ['microsoft azure sentiment analysis',  'microsoft text analytics'], 

'google_cloud_nlp':['google cloud sentiment analysis', 'google cloud natural language',
                'google cloud natural language api', 'google natural language api',
                'natural language api from google cloud'],
'watson_tone': ['ibm watson tone analyzer', 'tone analyzer','ibm watson natural language understanding', 'ibm watson\'s natural language understanding'],
'aws_comprehend': ['aws_comprehend'],
'paralleldots': ['paralleldots', 'paralleldots ai apis'],
'aylien': ['aylien', 'aylien sentiment analysis tool'] ,
    
    
"cloud_platforms_misc": ['google cloud', 'google cloud platform' , 'microsoft azure' ]     

}

# %%
#this is dictionary created from "used_for" parameter in meteor API and name of tools recorded there
#you cen see them here: https://meteor.opted.eu/search?dgraph.type=Tool 


meteor_dict = {
 "dictionaryresource": 
    ["afinn", "alpin sentiment dictionary", "anew", "affective norms for german sentiment terms", 
     "anti immigrant references in facebook posts", "berlin affective word list", 
     "berlin affective word list reloaded", "brand personality dictionary", 
     "civility and hostility in online comments", "corporate social responsibility dictionary", 
     "diction", "danish meta frames dictionary", "dictionary of affect in language", 
     "dictionary of defense spending", "dictionary of leadership traits", 
     "discrete emotion norms for nouns–berlin affective word list", "emosenticnet", 
     "emoji sentiment ranking 1.0", "emoticon module", "english game frames dictionary", 
     "fancat", "forest value dictionary", "french lexicoder sentiment dictionary", "galc", 
     "general inquirer dictionaries", "german political sentiment dictionary", 
     "germanpolarityclues", "incivil online comments", "inquiry based learning dictionary", 
     "kosac", "liwc", "laver and garry dictionary of policy positions", "lexicoder sentiment dictionary", 
     "lexicoder topic dictionaries", "loughran and mcdonald financial sentiment dictionary", 
     "lynching discourses dictionary", "measuring populism", "moral foundations dictionary", 
     "moral foundations dictionary for party manifestos", "multilingual sentiment analysis dictionaries", 
     "nrc word emotion association lexicon", "national taiwan university sentiment dictionary", 
     "nencki affective word list", "opinion lexicon", "panas x", "parental styles dictionary", 
     "personal values dictionary", "policy fields dictionary", "populism and eu n grams/policy n grams", 
     "populist language and targets dictionary", "presidential christian discourse dictionary", 
     "rpc lex: a dictionary to measure german right wing populist conspiracy discourse online", 
     "regressive imagery dictionary", "semantic ambiguity in traditional chinese", "sentistrength", 
     "sentiws", "sentiwordnet", "senticnet", "sentiment dictionary for german political language", 
     "sentiment140 lexicon", "soft skills list", "subjectivity lexicon", 
     "valence arousal and dominance dictionary", "wordstat sentiment dictionary", 
     "world ocean plurality dictionary", "emfdscore", "ed8", "ifeel", "labmt", "popdictr", "usent"],
 "documentsearch": 
    ["amcat", "elasticsearch", "piar", "solr", "textstat", "wordstat", "corpustools", "ilcm", "tm"],
 "manualcontentanalysis":
    ["amcat", "microsoft excel", "nvivo", "qda miner", "brat rapid annotation tool", "ilcm"],
 "crowdcoding": 
    ["amcat", "appen platform", "mona", "sentimentit"],
 "ngramextraction": 
    ["antconc", "automap", "nlp", "pattern", "wordij", "brat rapid annotation tool", "ilcm", "text2vec", "textreuse"],
 "keywordsincontext": 
    ["antconc", "lancsbox", "textstat", "wmatrix", "wordsmith", "wordstat", "corpustools", "ilcm", "quanteda"],
 "namedentityrecognition": 
    ["apache opennlp", "automap", "clavin", "context", "geoparser.io", "ibm watson", 
     "inca", "intelligent tagging", "jenextra", "semantria api", "sentiment political compass", 
     "stanford corenlp", "the edinburgh geoparser", "udpipe", "wordstat", "brat rapid annotation tool",
     "frog", "ilcm", "opennlp (cran)", "polyglot", "spacy", "spacyr"],
 "partofspeechtagging": 
    ["apache opennlp", "automap", "crie", "chasen", "context", "ibm watson", "inca", 
     "kh coder", "kuromoji", "lancsbox", "mila morphological analysis tool", "mecab", "nltk",
     "pattern", "semantria api", "sketch engine", "stanford corenlp", "udpipe", "wmatrix",
     "brat rapid annotation tool", "corpustools", "frog", "ilcm", "jieba", "jiebar",
     "korpus", "opennlp (cran)", "polyglot", "pymorphy2", "quanteda", "sehrnett", "spacy", "spacyr"],
 "tokenization": 
    ["apache opennlp", "crie", "chasen", "inca", "kh coder", "kuromoji", "mecab", 
     "nlp", "nltk", "pattern", "rapidminer", "stanford corenlp", "stanford word segmenter", 
     "t lab", "tool for the automatic analysis of cohesion", "udpipe", "wordseg", "jieba", 
     "jiebar", "korpus", "opennlp (cran)", "polyglot", "quanteda", "scikit learn", "spacy", "spacyr"],
 "dependencyparsing": 
    ["apache opennlp", "crie", "mila morphological analysis tool", "mecab", "nltk", 
     "stanford corenlp", "udpipe", "brat rapid annotation tool", "frog", "ilcm", "opennlp (cran)", "spacy", "spacyr"],
 "coreferenceresolution": 
    ["apache opennlp", "stanford corenlp", "brat rapid annotation tool", "opennlp (cran)"],
 "languagedetection": 
    ["apache opennlp", "cosmos", "tacit", "korpus", "langdetect", "newspaper3k", "opennlp (cran)", "polyglot", "textcat"],
 "dataconversion": 
    ["apache tika", "nitro pdf pro", "readtext", "spacy"],
 "dataparsing": 
    ["apache tika", "lexisnexistools", "nlp", "sentiment political compass", "boilerpipe", 
     "joinery", "news extract", "newspaper3k", "newspapers", "readtext", "rvest", "spacy", 
     "tm.plugin.factiva", "tm.plugin.lexisnexis", "tm.plugin.proquest", "trafilatura"],
 "textcleaning": 
    ["aspell", "dmi tcat", "emoticon module", "kh coder", "microsoft word", "nltk", "tacit", 
     "wordij", "wordstat", "boilerpipe", "corpustools", "ftfy", "hunspell", "ilcm", "justext", 
     "korpus", "pretext", "quanteda", "snowball", "spacy", "stm", "stopwords", "tidytext", 
     "tm", "wikibase reconcile", "word2number"],
 "stemming": 
    ["automap", "context", "nltk", "rapidminer", "t lab", "tacit", "arabicstemr", "corpustools", 
     "ilcm", "quanteda", "snowball", "spacy"],
 "semanticnetworkanalysis": 
    ["automap", "context", "kh coder", "t lab", "the macroscope", "wordij", "wordstat", "corpustools", "quanteda"],
 "wordfrequenciescorpusstatistics": 
    ["automap", "crie", "context", "dmi tcat", "discovertext", "fulltext.exe", "iramuteq", 
     "kh coder", "lancsbox", "mccalite", "nlp", "nltk", "readerbench", "sketch engine", "taltac2", 
     "textstat", "textometrica", "the macroscope", "wordij", "wmatrix", "wordsmith", "wordstat", 
     "korpus", "quanteda.textmodels", "scikit learn", "text2vec", "tidytext", "tm", "tweet.exe"],
 "dictionarydevelopment": 
    ["automap", "liwc", "dictvectorr"],
 "topicmodelling": 
    ["bertopic", "ctm", "context", "gibbslda++", "ibm watson", "inca", "mallet", "octis", 
     "pyctm", "sas® ondemand for academics", "t lab", "tacit", "top2vec", "wordstat", 
     "corpustools", "dynamic nmf", "gensim", "hsbm topicmodel", "ilcm", "lda", "ldatuning", 
     "rlda", "stm", "text2vec", "texteffect", "topicmodels"],
 "networkanalysis": 
    ["bibexcel", "cosmos", "dmi tcat", "discovertext", "fireant", "gephi", "issuecrawler", 
     "netlytic", "nodexl", "pajek", "pattern", "pulsar", "radices", "ucinet", "vosviewer", 
     "igraph", "network", "networkx", "quanteda", "sna", "tsm", "tweet.exe", "vosonsml"],
 "clustering": 
    ["bibexcel", "emergency situation awareness (esa)", "rapidminer", "t lab", "tacit", 
     "trust (trend clusters from spatio temporal data streams)"],
 "apiaccess": 
    ["birdsong analytics", "cosmos", "context", "coosto", "crimson hexagon", "dmi tcat", 
     "digital footprints", "emergency situation awareness (esa)", "fireant", "gnip", "guardianr", 
     "hashtagify", "inca", "nuvi", "netlytic", "netvizz", "piar", "pattern", "pulsar", "pushshift", 
     "radices", "reddit data reader via pushshift", "rfacebook", "sentiment political compass", 
     "sysomos", "tags", "telethon", "topsy", "tweet archiver", "tweet archivist", "vosviewer", 
     "web live", "youtube channel crawler", "youtube data tools", "archiveretriever", 
     "de tagesschau", "manifestor", "reddit comment scraper", "rtweet", "socialreaper", 
     "translater", "twarc", "tweepy", "twitter (cran)", "twitter (pypi)", "vosonsml", 
     "wikibase reconcile", "yourtwapperkeeper"],
 "botdetection": 
    ["botometer", "piar"],
 "documentscoring": 
    ["cass", "cosmos", "context", "ddr", "intelligent tagging", "lexicoder", "microsoft word", "mona", 
     "nrc hashtag", "opinionfinder", "panas t", "pattern", "perspective api", "rapidminer", 
     "readerbench", "seance", "so cal", "semantria api", "sentistrength", "sentiment140", 
     "stanford corenlp", "taales", "tacit", "the evaluative lexicon", 
     "tool for the automatic analysis of cohesion", "topsy", "umigon", "wordscores", 
     "austin", "corpustools", "emfdscore", "ifeel", "korpus", "labmt", "sasa", "usent", "vadersentiment", "wordfish"],
 "documentclassification": 
    ["cass", "emergency situation awareness (esa)", "galc", "inca", "lexicoder", "mona", "readerbench", 
     "semantria api", "t lab", "fasttext", 
     "isa: a fast, scalable and accurate algorithm for sentiment analysis of social media content", 
     "popdictr", "quanteda.textmodels", "stylest", "textcat"],
 "documentsimilarityscoring": 
    ["cassim", "copyscape", "docutoads", "lsafun", "rnewsflow", "tool for the automatic analysis of cohesion", 
     "wcopyfind", "corpustools", "quanteda", "quanteda.textmodels", "stylest", "text2vec", 
     "textdistance", "textmatch", "textreuse"],
 "geographicaldocumentclassification": 
    ["clavin", "geonames", "geoparser.io", "the edinburgh geoparser", "newsmap"],
 "lexicaldiversity": 
    ["crie", "korpus", "quanteda"],
 "facialrecognition": 
    ["character recognition tool"],
 "dictionaryanalysis": 
    ["context", "ddr", "diction", "liwc", "nltk", "netlytic", "t lab", "wordstat", "corpustools", 
     "ilcm", "quanteda", "tidytext", "tm"],
 "coordinatedlinksharingbehaviordetection": 
    ["coortweet", "coornet"],
 "datascraping": 
    ["coosto", "facepager", "httrack website copier", "instamancer", "issuecrawler", "microsoft excel", 
     "ncapture", "navicrawler", "pattern", "risjbot", "scrapebot", "scrapy", "selenium", "tacit", 
     "telethon", "archiveretriever", "fodira", "heritrix", "news please", "newspaper3k", "paperboy", 
     "requests", "rvest", "scrapy cluster", "trafilatura", "youtube dl", "yt dlp"],
 "networkvisualization": 
    ["dmi tcat", "fireant", "gephi", "issuecrawler", "netlytic", "nodexl", "piar", "textometrica", 
     "vosviewer", "igraph", "sna"],
 "supervisedmachinelearning": 
    ["discovertext", "libsvm", "mallet", "mona", "nltk", "pattern", "rtexttools", 
     "readme: software for automated content analysis", "superlearner", "sysomos", "tacit", "tensorflow", 
     "wordseg", "brat rapid annotation tool", "caret", "e1071", "fasttext", "grafzahl", "h2o", "keras", 
     "quanteda.textmodels", "randomforest", "readme2", "scikit learn", "tensorflow (r)", "text (cran)", 
     "vowpalwabbit", "xgboost"],
 "wordembedding": 
    ["glove", "mallet", "tensorflow", "tool for the automatic analysis of cohesion", "fasttext", "gensim", "h2o", 
     "partyembed", "polyglot", "spacy", "string2string", "subs2vec", "tensorflow (r)", "text (cran)", "text2vec", "word2vec"],
 "wordembeddingresource": 
    ["glove", "google news embedding", "the macroscope", "partyembed", "spacy", "subs2vec"],
 "unsupervisedmachinelearning": 
    ["glove", "fasttext", "word2vec"],
 "namedentitydisambiguation": 
    ["ibm watson", "jenextra", "sentiment political compass", "ilcm", "wikibase reconcile"],
 "lemmatization": 
    ["ibm watson", "kuromoji", "lancsbox", "nltk", "t lab", "tool for the automatic analysis of cohesion",
     "udpipe", "corpustools", "frog", "ilcm", "pymorphy2", "sehrnett", "spacy", "spacyr"],
 "textsummarization": ["ibm watson", "semantria api"],
 "speechtotext": ["ibm watson", "nvivo"],
 "corpuscomparison": ["iramuteq", "semdis", "wmatrix", "corpustools", "gensim", "quanteda", "wersim"],
 "hierarchicaldescendingclassification": ["iramuteq"],
 "authorshipattribution": ["jstylo anonymouth"],
 "datavisualization": 
    ["ldavis", "lsafun", "microsoft excel", "mona", "nuvi", "piar", "sentiment political compass", "tableau", 
     "the macroscope", "tweet archivist", "text (cran)", "wordcloud (cran)", "wordcloud (pypi)"],
 "transliteration": ["mila morphological analysis tool", "polyglot"],
 "morphologicalanalysis": ["mila morphological analysis tool", "brat rapid annotation tool", "polyglot"],
 "textpruning": ["nltk", "ilcm", "quanteda", "spacy"],
 "opticalcharacterrecognition": ["nitro pdf pro", "tesseract"],
 "validation": ["octis", "valitex", "oolong"],
 "htmlparsing": ["pattern", "beautifulsoup4"],
 "semantictagging": ["pattern", "wmatrix", "wordnet", "sehrnett"],
 "audioanalysis": ["praat"],
 "keywordextraction": 
    ["qda miner", "readerbench", "textstat", "wordstat", "jieba", "jiebar"],
 "lexicalresource": 
    ["semantic ambiguity in traditional chinese", "stimulstat: a lexical database for russian", "wordnet",
     "worldlex: twitter and blog word frequencies for 66 languages", "sehrnett"],
 "textscaling": 
    ["sparsefactoranalysis", "manifestor", "partyembed", "quanteda.textmodels", "spacy", "wordfish", "wordshoal"],
 "latentsemanticanalysis": 
    ["sparsefactoranalysis", "tool for the automatic analysis of cohesion", "quanteda.textmodels"],
 "quotationspeechextraction": ["stanford corenlp", "rsyntax"],
 "dependencytreeanalysis": ["brat rapid annotation tool", "rsyntax"],
 "deeplearning": ["keras", "text (cran)"],
 "lexicaldisambiguation": ["pywsd"],
 "lexicalsimilarity": ["string2string"],
 "stringalignment": ["string2string"],
 "texteffectestimation": ["texteffect"],
 "reinforcementlearning": ["vowpalwabbit"],
 "reconciliation": ["wikibase reconcile"]
}
